# %%
import warnings
warnings.filterwarnings(action='ignore',category=FutureWarning)
warnings.filterwarnings(action='ignore',category=DeprecationWarning)

# %%
import pandas as pd
a=pd.read_csv("HousingData.csv")
a.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
print('shape : ',a.shape)
a.info()
# Out:
# shape :  (506, 14)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
a.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
a.isnull().any().sum()
# Out:
# 6

# %%
a=a.dropna()

# %%
from sklearn.decomposition import PCA
import numpy as np

# %%
#a = np.random.rand(506, 14)

# %%
pc = PCA(n_components=10)

# %%
 model = pc.fit(a)

# %%
model.explained_variance_ratio_
# Out:
# array([8.07061648e-01, 1.59221902e-01, 2.20101891e-02, 7.19817152e-03,
#        1.92653262e-03, 1.39919373e-03, 4.54596185e-04, 3.73850450e-04,
#        2.47404921e-04, 7.05362386e-05])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(model.explained_variance_ratio_)
# Out:
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\3770738273.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(model.explained_variance_ratio_)
# <Axes: ylabel='Density'>

# %%
plt.hist(model.explained_variance_ratio_)
# Out:
# (array([8., 1., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([7.05362386e-05, 8.07696474e-02, 1.61468759e-01, 2.42167870e-01,
#         3.22866981e-01, 4.03566092e-01, 4.84265203e-01, 5.64964314e-01,
#         6.45663426e-01, 7.26362537e-01, 8.07061648e-01]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
a.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
a.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18   0.0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 5  394.12   5.21  28.7

# %%
categorical_var=a.drop(['CRIM', 'ZN', 'INDUS',  'NOX', 'RM', 'AGE', 'DIS',  'TAX','PTRATIO', 'LSTAT'],axis=1)

# %%
continuous_var=a.drop([ 'CHAS', 'RAD'],axis=1)

# %%
for i in categorical_var:
    if i != 'MEDV':
        sns.catplot(x=i,data=categorical_var,kind='count')
        sns.catplot(x=i,y='MEDV',data=categorical_var,kind='box')

# %%
import matplotlib.pyplot as plt
for i in continuous_var:
    if i != 'MEDV':
        
        sns.distplot(continuous_var[i])
        plt.show()
# Out:
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])
# C:\Users\Chanchal\AppData\Local\Temp\ipykernel_24440\1884753895.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(continuous_var[i])

# %%
for i in continuous_var:
    if i != 'MEDV':
        sns.scatterplot(x=i,y='MEDV',data=continuous_var)
        
        plt.show()

# %%
a_cor=a.corr()
a_cor
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.188075  0.391552 -0.051970  0.416160 -0.227170  0.341311
# ZN      -0.188075  1.000000 -0.521256 -0.033357 -0.515660  0.343210 -0.568174
# INDUS    0.391552 -0.521256  1.000000  0.049820  0.762737 -0.403068  0.642387
# CHAS    -0.051970 -0.033357  0.049820  1.000000  0.076661  0.095308  0.072644
# NOX      0.416160 -0.515660  0.762737  0.076661  1.000000 -0.316563  0.732540
# RM      -0.227170  0.343210 -0.403068  0.095308 -0.316563  1.000000 -0.248670
# AGE      0.341311 -0.568174  0.642387  0.072644  0.732540 -0.248670  1.000000
# DIS     -0.365052  0.645359 -0.696569 -0.095037 -0.768137  0.218713 -0.753547
# RAD      0.608667 -0.298773  0.591944  0.014102  0.628170 -0.236057  0.443585
# TAX      0.560841 -0.305768  0.734204 -0.026513  0.679824 -0.320561  0.504472
# PTRATIO  0.265428 -0.422164  0.395691 -0.104995  0.210216 -0.390686  0.264968
# B       -0.386254  0.169894 -0.344788  0.068913 -0.384257  0.123320 -0.281990
# LSTAT    0.461906 -0.415041  0.598156 -0.037113  0.593655 -0.636226  0.601137
# MEDV    -0.397230  0.406822 -0.510829  0.173701 -0.459054  0.723951 -0.407470
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.365052  0.608667  0.560841  0.265428 -0.386254  0.461906 -0.397230
# ZN       0.645359 -0.298773 -0.305768 -0.422164  0.169894 -0.415041  0.406822
# INDUS   -0.696569  0.591944  0.734204  0.395691 -0.344788  0.598156 -0.510829
# CHAS    -0.095037  0.014102 -0.026513 -0.104995  0.068913 -0.037113  0.173701
# NOX     -0.768137  0.628170  0.679824  0.210216 -0.384257  0.593655 -0.459054
# RM       0.218713 -0.236057 -0.320561 -0.390686  0.123320 -0.636226  0.723951
# AGE     -0.753547  0.443585  0.504472  0.264968 -0.281990  0.601137 -0.407470
# DIS      1.000000 -0.477075 -0.529603 -0.228840  0.285168 -0.505036  0.279547
# RAD     -0.477075  1.000000  0.900000  0.441949 -0.444135  0.510868 -0.416638
# TAX     -0.529603  0.900000  1.000000  0.446961 -0.435457  0.572218 -0.508864
# PTRATIO -0.228840  0.441949  0.446961  1.000000 -0.179816  0.395006 -0.543809
# B        0.285168 -0.444135 -0.435457 -0.179816  1.000000 -0.383783  0.347256
# LSTAT   -0.505036  0.510868  0.572218  0.395006 -0.383783  1.000000 -0.743450
# MEDV     0.279547 -0.416638 -0.508864 -0.543809  0.347256 -0.743450  1.000000

# %%
plt.figure(figsize=(10,7))
sns.heatmap(a_cor,annot=True)
# Out:
# <Axes: >

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/24/ec/ad387100fa3cc2b9b81af0829b5ecfe75ec5bb19dd7c19d4fea06fb81802/xgboost-2.0.3-py3-none-win_amd64.whl.metadata
#   Using cached xgboost-2.0.3-py3-none-win_amd64.whl.metadata (2.0 kB)
# Requirement already satisfied: numpy in c:\users\chanchal\anaconda3\new folder\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\chanchal\anaconda3\new folder\lib\site-packages (from xgboost) (1.10.1)
# Downloading xgboost-2.0.3-py3-none-win_amd64.whl (99.8 MB)
#    ---------------------------------------- 0.0/99.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/99.8 MB 667.8 kB/s eta 0:02:30
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.1/99.8 MB 1.2 MB/s eta 0:01:27
#    ---------------------------------------- 0.2/99.8 MB 372.0 kB/s eta 0:04:28
#    ---------------------------------------- 0.4/99.8 MB 755.6 kB/s eta 0:02:12
#    ---------------------------------------- 0.5/99.8 MB 900.2 kB/s eta 0:01:51
#    ---------------------------------------- 0.7/99.8 MB 1.2 MB/s eta 0:01:22
#    ---------------------------------------- 1.0/99.8 MB 1.5 MB/s eta 0:01:06
#    ---------------------------------------- 1.2/99.8 MB 1.7 MB/s eta 0:00:59
#     --------------------------------------- 1.4/99.8 MB 1.8 MB/s eta 0:00:54
#     --------------------------------------- 1.6/99.8 MB 1.9 MB/s eta 0:00:51
#     --------------------------------------- 2.0/99.8 MB 2.3 MB/s eta 0:00:43
#    ------- -------------------------------- 19.9/99.8 MB 9.5 MB/s eta 0:00:09
#    -------- ------------------------------- 20.4/99.8 MB 9.6 MB/s eta 0:00:09
#    -------- ------------------------------- 21.1/99.8 MB 10.1 MB/s eta 0:00:08
#    -------- ------------------------------- 21.6/99.8 MB 10.2 MB/s eta 0:00:08
#    -------- ------------------------------- 22.0/99.8 MB 10.1 MB/s eta 0:00:08
#    --------- ------------------------------ 22.6/99.8 MB 10.2 MB/s eta 0:00:08
#    --------- ------------------------------ 23.2/99.8 MB 10.1 MB/s eta 0:00:08
#    --------- ------------------------------ 23.7/99.8 MB 10.4 MB/s eta 0:00:08
#    --------- ------------------------------ 24.1/99.8 MB 10.2 MB/s eta 0:00:08
#    --------- ------------------------------ 24.3/99.8 MB 10.1 MB/s eta 0:00:08
#    --------- ------------------------------ 24.8/99.8 MB 9.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.2/99.8 MB 9.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 25.5/99.8 MB 9.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.3/99.8 MB 9.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.5/99.8 MB 9.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.6/99.8 MB 9.4 MB/s eta 0:00:08
#    ---------- ----------------------------- 26.6/99.8 MB 9.0 MB/s eta 0:00:09
#    ---------- ----------------------------- 26.8/99.8 MB 8.7 MB/s eta 0:00:09
#    ---------- ----------------------------- 26.8/99.8 MB 8.5 MB/s eta 0:00:09
#    ---------- ----------------------------- 27.2/99.8 MB 8.3 MB/s eta 0:00:09
#    ----------- ---------------------------- 27.7/99.8 MB 8.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 28.2/99.8 MB 8.2 MB/s eta 0:00:09
#    ----------- ---------------------------- 28.7/99.8 MB 8.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 29.1/99.8 MB 8.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 29.4/99.8 MB 8.0 MB/s eta 0:00:09
#    ------------ --------------------------- 30.0/99.8 MB 8.2 MB/s eta 0:00:09
#    ------------ --------------------------- 30.6/99.8 MB 8.6 MB/s eta 0:00:09
#    ------------ --------------------------- 31.2/99.8 MB 8.6 MB/s eta 0:00:08
#    ------------ --------------------------- 31.5/99.8 MB 8.4 MB/s eta 0:00:09
#    ------------ --------------------------- 31.7/99.8 MB 8.2 MB/s eta 0:00:09
#    ------------ --------------------------- 32.1/99.8 MB 8.3 MB/s eta 0:00:09
#    ------------- -------------------------- 32.4/99.8 MB 8.1 MB/s eta 0:00:09
#    ------------- -------------------------- 32.6/99.8 MB 7.9 MB/s eta 0:00:09
#    ------------- -------------------------- 33.2/99.8 MB 7.9 MB/s eta 0:00:09
#    ------------- -------------------------- 33.8/99.8 MB 7.9 MB/s eta 0:00:09
#    ------------- -------------------------- 34.4/99.8 MB 8.1 MB/s eta 0:00:09
#    -------------- ------------------------- 35.0/99.8 MB 8.2 MB/s eta 0:00:08
#    -------------------------------- ------- 81.2/99.8 MB 10.4 MB/s eta 0:00:02
#    -------------------------------- ------- 81.7/99.8 MB 10.4 MB/s eta 0:00:02
#    -------------------------------- ------- 82.0/99.8 MB 10.2 MB/s eta 0:00:02
#    --------------------------------- ------ 82.6/99.8 MB 10.1 MB/s eta 0:00:02
#    --------------------------------- ------ 83.1/99.8 MB 9.9 MB/s eta 0:00:02
#    --------------------------------- ------ 83.7/99.8 MB 9.8 MB/s eta 0:00:02
#    --------------------------------- ------ 84.2/99.8 MB 9.6 MB/s eta 0:00:02
#    --------------------------------- ------ 84.7/99.8 MB 9.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.3/99.8 MB 9.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 85.8/99.8 MB 9.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 86.2/99.8 MB 9.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 87.0/99.8 MB 9.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 87.5/99.8 MB 9.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.0/99.8 MB 10.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 88.5/99.8 MB 10.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.0/99.8 MB 10.4 MB/s eta 0:00:02
#    ----------------------------------- ---- 89.5/99.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 90.2/99.8 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 90.9/99.8 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------ --- 91.6/99.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------- -- 92.4/99.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------- -- 93.2/99.8 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------- -- 94.0/99.8 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 94.8/99.8 MB 13.4 MB/s eta 0:00:01
#    -------------------------------------- - 95.6/99.8 MB 13.4 MB/s eta 0:00:01
#    -------------------------------------- - 96.3/99.8 MB 13.9 MB/s eta 0:00:01
#    -------------------------------------- - 97.1/99.8 MB 14.5 MB/s eta 0:00:01
#    ---------------------------------------  97.9/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  98.4/99.8 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  98.9/99.8 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  99.5/99.8 MB 14.9 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------  99.7/99.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 99.8/99.8 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.0.3

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

# %%
from xgboost import XGBRegressor

# %%
x=a.drop(['MEDV'],axis=1)
y=a['MEDV']

# %%
x_s=StandardScaler()

# %%
x1=x_s.fit_transform(x)
x1=pd.DataFrame(x1)
x1.columns=x.columns

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,y,test_size=0.2,random_state=12)

# %%
lm=cross_val_score(LinearRegression(),x_train,y_train,cv=5)
rr=cross_val_score(Ridge(),x_train,y_train,cv=5)
lr=cross_val_score(Lasso(),x_train,y_train,cv=5)
gb=cross_val_score(GradientBoostingRegressor(),x_train,y_train,cv=5)
xgb=cross_val_score(XGBRegressor(),x_train,y_train,cv=5)
#pr=cross_val_score(PolynomialFeatures(),x_train,y_train,cv=5)

# %%
print("cross validation score:")
print("linear regression :",lm,lm.mean(),lm.std())
print("ridge regression :",rr,rr.mean(),rr.std())
print("lasso regression :",lr,lr.mean(),lr.std())
print("gradient boosting :",gb,gb.mean(),gb.std())
print("XG boost :",xgb,xgb.mean(),xgb.std())
# Out:
# cross validation score:
# linear regression : [0.76759973 0.64304383 0.66122829 0.71647672 0.76655059] 0.7109798316472735 0.05179701652903747
# ridge regression : [0.7672059  0.64369347 0.66045751 0.72121329 0.76704615] 0.7119232642762872 0.051932714651555446
# lasso regression : [0.66027415 0.58866398 0.57935516 0.76932721 0.70364423] 0.6602529446215563 0.07134343834825815
# gradient boosting : [0.93180411 0.68260277 0.86379928 0.8836614  0.90075666] 0.8525248453557234 0.0878426109787181
# XG boost : [0.88689647 0.71847128 0.85526723 0.89455981 0.89491804] 0.8500225656439232 0.0673677999803777

# %%
lm=LinearRegression()

# %%
model=lm.fit(x_train,y_train)
pred_test=model.predict(x_test)
print("coeff -",model.coef_)
print("intercept -",model.intercept_)
# Out:
# coeff - [-0.91254123  1.21627824  0.3699639   0.75003429 -2.25624336  2.9597808
#  -0.41850131 -3.25721091  2.63859371 -2.43290314 -2.08670718  0.76726453
#  -3.06464495]
# intercept - 22.355112376218862

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  81.66469835178383 %
# error -  9.840395692626752

# %%
rr=Ridge()

# %%
param={"alpha":[10,1,0.1,0.01,0.001,0.0001,0.00001]}
grid=GridSearchCV(estimator=rr,param_grid=param,cv=3,scoring='neg_mean_squared_error')
grid.fit(x_train,y_train)
print(grid.best_params_)
pd.DataFrame(grid.cv_results_)
# Out:
# {'alpha': 10}
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.004810      0.000293         0.004079    1.057454e-04          10
# 1       0.004758      0.000460         0.002641    4.565875e-04           1
# 2       0.004013      0.000017         0.002998    2.973602e-07         0.1
# 3       0.004311      0.000496         0.002999    3.972053e-06        0.01
# 4       0.004256      0.000188         0.003365    5.086987e-04       0.001
# 5       0.004345      0.000461         0.002660    4.599690e-04      0.0001
# 6       0.003997      0.000004         0.003339    4.689636e-04     0.00001
#
#               params  split0_test_score  split1_test_score  split2_test_score  \
# 0      {'alpha': 10}         -28.893460         -25.642706         -23.377799
# 1       {'alpha': 1}         -28.711490         -25.691524         -25.061884
# 2     {'alpha': 0.1}         -28.725856         -25.709962         -25.389889
# 3    {'alpha': 0.01}         -28.728216         -25.712049         -25.425550
# 4   {'alpha': 0.001}         -28.728463         -25.712260         -25.429147
# 5  {'alpha': 0.0001}         -28.728488         -25.712281         -25.429507
# 6   {'alpha': 1e-05}         -28.728490         -25.712284         -25.429543
#
#    mean_test_score  std_test_score  rank_test_score
# 0       -25.971322        2.263717                1
# 1       -26.488299        1.592910                2
# 2       -26.608569        1.502840                3
# 3       -26.621938        1.493949                4
# 4       -26.623290        1.493062                5
# 5       -26.623425        1.492974                6
# 6       -26.623439        1.492965                7

# %%
rr=Ridge(alpha=0.00001)
model=rr.fit(x_train,y_train)
pred_test=model.predict(x_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  81.66469968776028 %
# error -  9.840394975619905

# %%
pf=PolynomialFeatures(degree=2)

# %%
model=pf.fit_transform(x_train)
model_test=pf.fit_transform(x_test)

# %%
model1=lm.fit(model,y_train)
pred=model1.predict(model_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  48.32574802478135 %
# error -  27.73311812986302

# %%
gb=GradientBoostingRegressor()
gb
# Out:
# GradientBoostingRegressor()

# %%
param={'alpha':[0.9,0.1,0.01,0.001,0.0001,0.00001],'max_depth':[2,3,5,7,9,10,15,20]}
grid=GridSearchCV(estimator=gb,param_grid=param,cv=3,scoring='neg_mean_squared_error')
grid.fit(x_train,y_train)
print(grid.best_params_)
pd.DataFrame(grid.cv_results_)
# Out:
# {'alpha': 0.001, 'max_depth': 3}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0        0.327845      0.012884         0.010413        0.007363         0.9
# 1        0.437887      0.013121         0.010627        0.007519         0.9
# 2        0.512081      0.051788         0.005208        0.007366         0.9
# 3        0.791454      0.085894         0.005218        0.007379         0.9
# 4       55.649718     77.007499         0.006720        0.006576         0.9
# 5        0.604553      0.146281         0.004026        0.002189         0.9
# 6        0.552078      0.054692         0.006536        0.006416         0.9
# 7        1.029916      0.537791         0.005216        0.007377         0.9
# 8        0.357708      0.017477         0.006886        0.006523         0.1
# 9        0.491620      0.017960         0.000000        0.000000         0.1
# 10       0.540435      0.123422         0.000000        0.000000         0.1
# 11       0.875513      0.116813         0.005214        0.007374         0.1
# 12       1.366364      0.020713         0.010009        0.007089         0.1
# 13       1.170120      0.246349         0.005209        0.007366         0.1
# 14       1.513540      0.218501         0.005210        0.007368         0.1
# 15       1.162457      0.232557         0.000000        0.000000         0.1
# 16       0.263966      0.098346         0.008184        0.007457        0.01
# 17       0.496993      0.006333         0.000000        0.000000        0.01
# 18       0.459837      0.234648         0.010386        0.007344        0.01
# 19       1.077280      0.014212         0.005242        0.007414        0.01
# 20       1.286222      0.111647         0.005202        0.007357        0.01
# 21       0.921439      0.171724         0.003515        0.004972        0.01
# 22       1.544183      0.232036         0.010414        0.007364        0.01
# 23       1.772549      0.077385         0.002264        0.003202        0.01
# 24       0.373933      0.004745         0.012407        0.002682       0.001
# 25       0.506491      0.006715         0.000000        0.000000       0.001
# 26       0.680538      0.115248         0.000000        0.000000       0.001
# 27       0.731977      0.076671         0.000000        0.000000       0.001
# 28       1.350127      0.010872         0.005214        0.007373       0.001
# 29       1.443571      0.057208         0.005206        0.007362       0.001
# 30       1.590197      0.027887         0.010434        0.007378       0.001
# 31       1.384954      0.241445         0.005209        0.007367       0.001
# 32       0.350174      0.006855         0.005215        0.007375      0.0001
# 33       0.465666      0.014246         0.010413        0.007363      0.0001
# 34       0.762218      0.031128         0.005212        0.007370      0.0001
# 35       1.086721      0.026942         0.010412        0.007363      0.0001
# 36       1.234158      0.103096         0.005220        0.007382      0.0001
# 37       1.003838      0.021498         0.000000        0.000000      0.0001
# 38       1.661746      0.065773         0.013036        0.010018      0.0001
# 39       1.365663      0.349865         0.005207        0.007364      0.0001
# 40       0.366459      0.005914         0.005215        0.007376     0.00001
# 41       0.507142      0.006527         0.000000        0.000000     0.00001
# 42       0.627105      0.136649         0.005217        0.007378     0.00001
# 43       0.848065      0.123635         0.005242        0.007413     0.00001
# 44       1.415001      0.039222         0.010819        0.007667     0.00001
# 45    1343.000853   1897.350871         0.003849        0.002791     0.00001
# 46       0.692472      0.096741         0.003676        0.001711     0.00001
# 47       0.871636      0.336274         0.004268        0.001870     0.00001
#
#    param_max_depth                              params  split0_test_score  \
# 0                2      {'alpha': 0.9, 'max_depth': 2}         -21.698867
# 1                3      {'alpha': 0.9, 'max_depth': 3}         -20.718749
# 2                5      {'alpha': 0.9, 'max_depth': 5}         -23.325553
# 3                7      {'alpha': 0.9, 'max_depth': 7}         -27.023854
# 4                9      {'alpha': 0.9, 'max_depth': 9}         -28.665972
# 5               10     {'alpha': 0.9, 'max_depth': 10}         -31.107022
# 6               15     {'alpha': 0.9, 'max_depth': 15}         -35.219317
# 7               20     {'alpha': 0.9, 'max_depth': 20}         -36.612588
# 8                2      {'alpha': 0.1, 'max_depth': 2}         -21.653330
# 9                3      {'alpha': 0.1, 'max_depth': 3}         -19.720977
# 10               5      {'alpha': 0.1, 'max_depth': 5}         -22.982848
# 11               7      {'alpha': 0.1, 'max_depth': 7}         -26.435226
# 12               9      {'alpha': 0.1, 'max_depth': 9}         -28.732572
# 13              10     {'alpha': 0.1, 'max_depth': 10}         -30.118328
# 14              15     {'alpha': 0.1, 'max_depth': 15}         -34.485350
# 15              20     {'alpha': 0.1, 'max_depth': 20}         -34.457209
# 16               2     {'alpha': 0.01, 'max_depth': 2}         -21.625296
# 17               3     {'alpha': 0.01, 'max_depth': 3}         -20.116158
# 18               5     {'alpha': 0.01, 'max_depth': 5}         -22.963687
# 19               7     {'alpha': 0.01, 'max_depth': 7}         -27.146996
# 20               9     {'alpha': 0.01, 'max_depth': 9}         -29.715699
# 21              10    {'alpha': 0.01, 'max_depth': 10}         -29.653000
# 22              15    {'alpha': 0.01, 'max_depth': 15}         -36.949104
# 23              20    {'alpha': 0.01, 'max_depth': 20}         -34.526428
# 24               2    {'alpha': 0.001, 'max_depth': 2}         -21.906465
# 25               3    {'alpha': 0.001, 'max_depth': 3}         -19.349642
# 26               5    {'alpha': 0.001, 'max_depth': 5}         -24.046076
# 27               7    {'alpha': 0.001, 'max_depth': 7}         -27.137551
# 28               9    {'alpha': 0.001, 'max_depth': 9}         -29.623636
# 29              10   {'alpha': 0.001, 'max_depth': 10}         -34.022498
# 30              15   {'alpha': 0.001, 'max_depth': 15}         -35.348945
# 31              20   {'alpha': 0.001, 'max_depth': 20}         -32.467389
# 32               2   {'alpha': 0.0001, 'max_depth': 2}         -21.907713
# 33               3   {'alpha': 0.0001, 'max_depth': 3}         -19.340727
# 34               5   {'alpha': 0.0001, 'max_depth': 5}         -23.810375
# 35               7   {'alpha': 0.0001, 'max_depth': 7}         -28.076312
# 36               9   {'alpha': 0.0001, 'max_depth': 9}         -29.642816
# 37              10  {'alpha': 0.0001, 'max_depth': 10}         -32.760196
# 38              15  {'alpha': 0.0001, 'max_depth': 15}         -35.316160
# 39              20  {'alpha': 0.0001, 'max_depth': 20}         -34.531964
# 40               2    {'alpha': 1e-05, 'max_depth': 2}         -21.893983
# 41               3    {'alpha': 1e-05, 'max_depth': 3}         -20.133725
# 42               5    {'alpha': 1e-05, 'max_depth': 5}         -23.848303
# 43               7    {'alpha': 1e-05, 'max_depth': 7}         -26.794828
# 44               9    {'alpha': 1e-05, 'max_depth': 9}         -30.813450
# 45              10   {'alpha': 1e-05, 'max_depth': 10}         -30.923253
# 46              15   {'alpha': 1e-05, 'max_depth': 15}         -32.383580
# 47              20   {'alpha': 1e-05, 'max_depth': 20}         -31.557252
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0          -12.105318         -11.155222       -14.986469        4.762205
# 1          -10.133343         -10.114145       -13.655412        4.994539
# 2          -10.847802         -11.746600       -15.306652        5.682080
# 3          -14.097329         -15.718951       -18.946711        5.749643
# 4          -16.591584         -16.392139       -20.549898        5.739508
# 5          -16.557267         -17.964496       -21.876262        6.552368
# 6          -18.733857         -17.744849       -23.899341        8.014609
# 7          -19.058326         -18.991671       -24.887528        8.290914
# 8          -12.105318         -11.119259       -14.959302        4.750480
# 9           -9.870423          -9.852771       -13.148057        4.647762
# 10         -11.176162         -12.168484       -15.442498        5.347201
# 11         -14.453797         -15.377577       -18.755533        5.443443
# 12         -16.303845         -16.519106       -20.518508        5.808885
# 13         -16.878765         -17.633717       -21.543604        6.071074
# 14         -18.891565         -17.552010       -23.642975        7.686197
# 15         -19.209020         -17.711506       -23.792578        7.565774
# 16         -12.141085         -11.217458       -14.994613        4.703739
# 17          -9.972085          -9.887852       -13.325365        4.801939
# 18         -10.374926         -11.673612       -15.004075        5.653212
# 19         -14.501740         -15.539918       -19.062884        5.732021
# 20         -16.357703         -16.125091       -20.732831        6.352557
# 21         -16.782871         -18.900688       -21.778853        5.634591
# 22         -18.652058         -18.121766       -24.574309        8.752979
# 23         -19.043755         -18.865487       -24.145223        7.340981
# 24         -12.095740         -11.117769       -15.039992        4.871718
# 25          -9.897938          -9.834922       -13.027500        4.470503
# 26         -10.997157         -11.682680       -15.575304        5.996274
# 27         -14.184274         -15.663129       -18.994985        5.789231
# 28         -16.442334         -16.096381       -20.720783        6.296851
# 29         -16.879148         -17.690408       -22.864018        7.897185
# 30         -19.312193         -18.734150       -24.465096        7.699661
# 31         -18.698038         -17.900701       -23.022043        6.686796
# 32         -12.097104         -11.220054       -15.074957        4.844737
# 33          -9.867378         -10.169274       -13.125793        4.396350
# 34         -10.645546         -11.741580       -15.399167        5.964430
# 35         -14.577047         -16.389072       -19.680811        5.982430
# 36         -16.462132         -16.417399       -20.840783        6.224004
# 37         -16.628845         -17.708717       -22.365919        7.363073
# 38         -18.870074         -17.842122       -24.009452        8.006056
# 39         -18.786787         -18.891700       -24.070150        7.397743
# 40         -12.059973         -11.118523       -15.024160        4.872880
# 41         -10.044121          -9.838230       -13.338692        4.805549
# 42         -10.655433         -11.984547       -15.496095        5.930777
# 43         -14.448852         -15.075804       -18.773161        5.677947
# 44         -16.639909         -15.622879       -21.025413        6.933630
# 45         -16.584985         -18.448027       -21.985421        6.365603
# 46         -19.050962         -18.468549       -23.301030        6.426732
# 47         -18.833951         -17.937720       -22.776307        6.219836
#
#     rank_test_score
# 0                 8
# 1                 6
# 2                14
# 3                21
# 4                26
# 5                33
# 6                42
# 7                48
# 8                 7
# 9                 3
# 10               16
# 11               19
# 12               25
# 13               31
# 14               40
# 15               41
# 16                9
# 17                4
# 18               10
# 19               23
# 20               28
# 21               32
# 22               47
# 23               45
# 24               12
# 25                1
# 26               18
# 27               22
# 28               27
# 29               37
# 30               46
# 31               38
# 32               13
# 33                2
# 34               15
# 35               24
# 36               29
# 37               35
# 38               43
# 39               44
# 40               11
# 41                5
# 42               17
# 43               20
# 44               30
# 45               34
# 46               39
# 47               36

# %%
gb=GradientBoostingRegressor(alpha=0.01,max_depth=3)
model=gb.fit(x_train,y_train)
pred_test=model.predict(x_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  90.09050632665608 %
# error -  5.31833840152679

# %%
xgb=XGBRegressor()
xgb
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
param={'base_score':[0.9,0.5,0.1,0.01,0.001,0.0001,0.00001],'max_depth':[2,3,5,7,9,10,15,20]}
grid=GridSearchCV(estimator=xgb,param_grid=param,cv=3,scoring='neg_mean_squared_error')
grid.fit(x_train,y_train)
print(grid.best_params_)
# Out:
# {'base_score': 0.5, 'max_depth': 5}

# %%
xgb=XGBRegressor(base_score=0.01,max_depth=5)

# %%
model=xgb.fit(x_train,y_train)
pred_test=model.predict(x_test)

# %%
print("TEST DATA:")
print("accuracy - ",r2_score(y_pred=pred_test,y_true=y_test)*100,"%")
print("error - ",mean_squared_error(y_pred=pred_test,y_true=y_test))
# Out:
# TEST DATA:
# accuracy -  90.0736795717309 %
# error -  5.327369173415008

# %%
pd.DataFrame(pred_test)
# Out:
#             0
# 0   25.359541
# 1   22.211124
# 2   22.327421
# 3   22.776394
# 4   10.001395
# ..        ...
# 74  24.634104
# 75  21.395374
# 76  27.056948
# 77  36.149105
# 78  20.299644
#
# [79 rows x 1 columns]
